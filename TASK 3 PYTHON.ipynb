# %%
def simple_interest(p,r,t):
    si=(p*r*t)/100
    return si
def compound_interest(p,r,t):
    amount=p*(1+r/100)**t
    ci=amount-p
    return ci
n=int(input("enter the number of customers"))
for i in range(n):
    print("\n customers",i+1)
    p=int(input("enter the principle:"))
    r=int(input("enter the rate:"))
    t=int(input("enter the time:"))
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    print("simple_interest",si)
    print("compound_interest",ci)
# Out:
# enter the number of customers 3
#  customers 1
# enter the principle: 10000
# enter the rate: 2
# enter the time: 3
# simple_interest 600.0
# compound_interest 612.0800000000017
#
#  customers 2
# enter the principle: 50000
# enter the rate: 5
# enter the time: 3
# simple_interest 7500.0
# compound_interest 7881.250000000007
#
#  customers 3
# enter the principle: 45000
# enter the rate: 4
# enter the time: 5
# simple_interest 9000.0
# compound_interest 9749.380608000007
