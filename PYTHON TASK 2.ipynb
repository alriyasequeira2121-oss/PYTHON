# %%
customer={"name": "Alriya",
          "balance": 5000}
if customer ["balance"] > 2000:
  print("Good balance")
else:
  print("Low balance")
# Out:
# Good balance

# %%
account=("Aiswarya", "Savings")
if account[1]=="Savings":
  print("Savings Account")
# Out:
# Savings Account

# %%
customers = ["Riya","Andrea","Deepika"]
for name in customers:
  print(name)
# Out:
# Riya
# Andrea
# Deepika

# %%
transactions=[600,-200,1000,-700]
for amount in transactions:
  if amount > 0:
    print("Credit")
  else:
    print("Debit")
# Out:
# Credit
# Debit
# Credit
# Debit

# %%
amounts=[2100, 45000, 210, 6000, 5000]
for amount in amounts:
  if amount >5000:
    print("Large")
  else:
    print("Small")
# Out:
# Small
# Large
# Small
# Large
# Small

# %%
balance=10000
amount=float(input("Enter debit amount"))
if amount <=balance:
  print("Debit successful")
else:
  print("Insufficient balance")
# Out:
# Enter debit amount 21100
# Insufficient balance

# %%
transactions=[("Credit", 1000),
                ("Debit", 500)]
for t_type, amount in transactions:
  if t_type=="Credit":
    print("Added")
  elif t_type=="Debit":
    print("Deducted")
